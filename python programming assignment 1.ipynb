# %% [markdown]
# ### 1. Write a Python program to print &quot;Hello Python&quot;?

# %%
print("hello python")
# Out:
# hello python

# %% [markdown]
# ### 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a=int(input("enter value of a : "))
b=int(input("enter value of b : "))
print("Addition= ",a+b)
print("division=",float(a/b))
# Out:
# enter value of a : 5
# enter value of b : 2
# Addition=  7
# division= 2.5

# %% [markdown]
# ### 3. Write a Python program to find the area of a triangle?

# %%
base=float(input("enter value of base length of triangle: "))
height=float(input("enter value of height of triangle "))
area=0.5*base*height
print("Area of triangle= ",area)
# Out:
# enter value of base length of triangle: 2
# enter value of height of triangle 5
# Area of triangle=  5.0

# %% [markdown]
# ### 4.Write a python program to swapp two numbers ?

# %%
#method-1
a=int(input("a= "))
b=int(input("b= "))
a,b=b,a
print("new a= ",a)
print("new b= ",b)
# Out:
# a= 1
# b= 2
# new a=  2
# new b=  1

# %% [markdown]
# ### 5. Write a Python program to generate a random number?

# %%
# Program to generate a random number between 0 and 9

# importing the random module
import random

print(random.randint(0,1000))
# Out:
# 663
